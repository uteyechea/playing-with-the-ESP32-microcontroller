# %%
import dash
from dash.dependencies import Output, Input
import dash_core_components as dcc
import dash_html_components as html

# %%
import plotly
import plotly.graph_objs as go
from collections import deque
import serial
import re

def sensor():
    ser = serial.Serial('COM4', baudrate=115200, timeout=1)
    return ser

# %%
ser = sensor()

# %%
def dataCollector(ser):
    data = ser.readline().decode('ascii')
    y,z=0,0
    try:
        y,z=re.findall('\d+\.\d+|\d+', data)
    except:
        print('Couldn\'t find numerical values using regex')
    return y,z
# Out:
#   File "<ipython-input-6-00161fbf2ebd>", line 6
#     return y,z
#          ^
# SyntaxError: invalid syntax

# %%
while True:
    print(dataCollector(ser))
# Out:
# Couldn't find numerical values using regex
# (0, 0)
# Couldn't find numerical values using regex
# (0, 0)
# Couldn't find numerical values using regex
# (0, 0)
# Couldn't find numerical values using regex
# (0, 0)
# Couldn't find numerical values using regex
# (0, 0)
# Couldn't find numerical values using regex
# (0, 0)
# Couldn't find numerical values using regex
# (0, 0)
# Couldn't find numerical values using regex
# (0, 0)
# Couldn't find numerical values using regex
# (0, 0)
# Couldn't find numerical values using regex
# (0, 0)
# Couldn't find numerical values using regex
# (0, 0)
# Couldn't find numerical values using regex
# (0, 0)
# Couldn't find numerical values using regex
# (0, 0)
# Couldn't find numerical values using regex
# (0, 0)
# Couldn't find numerical values using regex
# (0, 0)
# Couldn't find numerical values using regex
# (0, 0)
# Couldn't find numerical values using regex
# (0, 0)
# Couldn't find numerical values using regex
# (0, 0)
# Couldn't find numerical values using regex
# (0, 0)
# Couldn't find numerical values using regex
# (0, 0)
# Couldn't find numerical values using regex
# (0, 0)
# Couldn't find numerical values using regex
# (0, 0)
# Couldn't find numerical values using regex
# (0, 0)
# Couldn't find numerical values using regex
# (0, 0)
# Couldn't find numerical values using regex
# (0, 0)
# Couldn't find numerical values using regex
# (0, 0)
# Couldn't find numerical values using regex
# (0, 0)
# Couldn't find numerical values using regex
# (0, 0)
# Couldn't find numerical values using regex
# (0, 0)
# Couldn't find numerical values using regex
# (0, 0)
# Couldn't find numerical values using regex
# (0, 0)
# ('2', '53.3')
# Couldn't find numerical values using regex
# (0, 0)
# ('9', '53.3')
# ('13', '53.3')
# ('7', '53.3')
# ('3', '52.8')
# Couldn't find numerical values using regex
# (0, 0)
# Couldn't find numerical values using regex
# (0, 0)
# Couldn't find numerical values using regex
# (0, 0)
# Couldn't find numerical values using regex
# (0, 0)
# ('1', '53.3')
# Couldn't find numerical values using regex
# (0, 0)
# ('4', '52.8')
# ('1', '53.3')
# ('5', '53.3')
# Couldn't find numerical values using regex
# (0, 0)
# ('7', '53.3')
# ('15', '53.3')
# ('11', '53.3')
# ('8', '53.3')
# ('17', '52.8')
# ('30', '53.3')
# ('2', '53.3')
# ('11', '53.3')
# ('27', '53.3')
# ('17', '53.3')
# ('7', '52.8')
# ('19', '52.8')
# ('15', '53.3')
# ('10', '53.3')
# ('35', '53.3')
# ('8', '53.3')
# ('4', '53.3')
# ('45', '53.3')
# ('3', '53.3')
# ('24', '53.3')
# ('21', '53.3')
# ('5', '53.3')
# ('5', '53.3')
# Couldn't find numerical values using regex
# (0, 0)
# Couldn't find numerical values using regex
# (0, 0)
# Couldn't find numerical values using regex
# (0, 0)
# Couldn't find numerical values using regex
# (0, 0)
# Couldn't find numerical values using regex
# (0, 0)
# Couldn't find numerical values using regex
# (0, 0)
# Couldn't find numerical values using regex
# (0, 0)
# Couldn't find numerical values using regex
# (0, 0)
# Couldn't find numerical values using regex
# (0, 0)
# ('0', '0')
# Couldn't find numerical values using regex
# (0, 0)
# Couldn't find numerical values using regex
# (0, 0)
# Couldn't find numerical values using regex
# (0, 0)
# Couldn't find numerical values using regex
# (0, 0)
# Couldn't find numerical values using regex
# (0, 0)
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-5-88340b7b257a> in <module>
#       1 while True:
# ----> 2     print(dataCollector(ser))
#
# <ipython-input-4-6eee37dccc4e> in dataCollector(ser)
#       1 def dataCollector(ser):
# ----> 2     data = ser.readline().decode('ascii')
#       3     y,z=0,0
#       4     try:
#       5         y,z=re.findall('\d+\.\d+|\d+', data)
#
# UnicodeDecodeError: 'ascii' codec can't decode byte 0xc9 in position 17: ordinal not in range(128)

# %%
X = deque(maxlen=20)
X.append(1)
Y = deque(maxlen=20)
Y.append(1)

app = dash.Dash(__name__)

colors = {
    'background': '#111111',
    'text': '#7FDBFF'
}


app.layout = html.Div(style={'backgroundColor': colors['background']}, children=[
    html.H1(
        children='Esp32: Hall Sensor Realtime Chart',
        style={
            'textAlign': 'center',
            'color': colors['text']
        }
    ),

    html.Div(children='The integrated Hall Sensor on the esp32 is\
             used to detect the presence of magnetism \n then via the \
             serial port it transfers its data readings in realtime,\
             finally all data is presented in a live chart using dash (python).', style={
        'textAlign': 'center',
        'color': colors['text']
    }),

    html.Div(
        [
            dcc.Graph(id='live-graph', animate=True),
            dcc.Interval(
                id='graph-update',
                interval=1000,
                n_intervals=0
            ),
        ]
    )



])


@app.callback(Output('live-graph', 'figure'),
              [Input('graph-update', 'n_intervals')])

def update_graph_scatter(n):
    X.append(X[-1]+1)
    data = float(dataCollector())
    Y.append(data)
    data = plotly.graph_objs.Scatter(
        x=list(X),
        y=list(Y),
        name='Scatter',
        mode='lines+markers'
    )
    return {'data': [data], 'layout': go.Layout(xaxis=dict(range=[min(X), max(X)]),
                                                yaxis=dict(range=[min(Y), max(Y)]),)}


if __name__ == '__main__':
    sensor()
    app.run_server(debug=True)

# %%
findObj=re.findall('\d+\.\d+|\d+', data)
x,y=findObj
#if findObj:
 #       print(findObj.group())
        #y = float(findObj.group())
        #print('re',y)

# %%
data=' 3 53.3'

# %%
x

# %%
y
